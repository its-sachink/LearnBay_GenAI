# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IPL2013.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Displaying first few records of DataFrame

# %%
pd.set_option('display.max_columns',30)

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS  \
# 0           0      0.00         0        0.0              0       0   0
# 1         657     71.41       185       37.6              0       0   0
# 2        1269     80.62       288       32.9              0     167  39
# 3         241     84.56        51       36.8              0      58  11
# 4          79     45.93         0        0.0              0    1317  71
#
#      AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  AUCTION YEAR  \
# ...

# %% [markdown]
# ## Basic Info the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df_describe = df.describe(include = 'all').T # T is transpose, include all have all the columns(numerical and categorical)

# %%
df_describe
df_describe().T
# Out:
#                count unique          top freq           mean            std  \
# Sl.NO.         130.0    NaN          NaN  NaN           65.5      37.671829
# PLAYER NAME      130    130  Abdulla, YA    1            NaN            NaN
# AGE            130.0    NaN          NaN  NaN       2.092308       0.576627
# COUNTRY          130     10          IND   53            NaN            NaN
# TEAM             130     17          CSK   14            NaN            NaN
# PLAYING ROLE     130      4       Bowler   44            NaN            NaN
# T-RUNS         130.0    NaN          NaN  NaN    2166.715385    3305.646757
# T-WKTS         130.0    NaN          NaN  NaN      66.530769     142.676855
# ODI-RUNS-S     130.0    NaN          NaN  NaN    2508.738462    3582.205625
# ODI-SR-B       130.0    NaN          NaN  NaN      71.164385       25.89844
# ODI-WKTS       130.0    NaN          NaN  NaN      76.076923      111.20507
# ...

# %%
len(df_describe)
# Out:
# 26

# %%
df.shape
# Out:
# (130, 26)

# %% [markdown]
# Slicing and Indexing of Dataframe

# %%
df[0:5]  #equivalent to df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS  \
# 0           0      0.00         0        0.0              0       0   0
# 1         657     71.41       185       37.6              0       0   0
# 2        1269     80.62       288       32.9              0     167  39
# 3         241     84.56        51       36.8              0      58  11
# 4          79     45.93         0        0.0              0    1317  71
#
#      AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  AUCTION YEAR  \
# ...

# %%
df[-5:] #equivalent to df.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS  \
# 125           0      0.00         0        0.0              0      49  16
# 126        6814     75.78         3       86.6              1       3   3
# 127        8051     87.58       109       44.3              1    1237  66
# 128         790     73.55       278       35.4              0      99  23
# 129         343     95.81       108       39.4              0      11  10
#
# ...

# %%
df[['PLAYER NAME']][0:5]
# Out:
#     PLAYER NAME
# 0   Abdulla, YA
# 1  Abdur Razzak
# 2   Agarkar, AB
# 3     Ashwin, R
# 4  Badrinath, S

# %%
df[['PLAYER NAME','COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %% [markdown]
# ## SPECIFIC ROW AND COLUMNS

# %%
df.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %% [markdown]
# ## Value Counts

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
df['COUNTRY'].value_counts(normalize = True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %% [markdown]
# ## Crosstabulation -- occurances for the combination of values for categorical columns

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE']) ## can be used before chi square test
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %% [markdown]
# ## Sorting Datasets

# %%
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE', ascending = False).reset_index().head()
# Out:
#    index    PLAYER NAME  SOLD PRICE
# 0    127   Yuvraj Singh     1800000
# 1     50       Kohli, V     1800000
# 2    111  Tendulkar, SR     1800000
# 3     93      Sehwag, V     1800000
# 4    113     Tiwary, SS     1600000

# %% [markdown]
# ## Creating New Columns

# %%
df['PREMIUM'] = df['SOLD PRICE']-df['BASE PRICE']

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S  HS  \
# 0           0      0.00         0        0.0              0       0   0
# 1         657     71.41       185       37.6              0       0   0
# 2        1269     80.62       288       32.9              0     167  39
# 3         241     84.56        51       36.8              0      58  11
# 4          79     45.93         0        0.0              0    1317  71
#
#      AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  AUCTION YEAR  \
# ...

# %%
df[['PLAYER NAME','PREMIUM']].sort_values('PREMIUM',ascending = False)[0:5] # Top 5 players with the highest premium
# Out:
#        PLAYER NAME  PREMIUM
# 50        Kohli, V  1650000
# 113     Tiwary, SS  1500000
# 127   Yuvraj Singh  1400000
# 111  Tendulkar, SR  1400000
# 93       Sehwag, V  1400000

# %%
df['PREMIUM'].sort_values(ascending = False)[0:5] # Top 5 players with the highest premium
# Out:
# 50     1650000
# 113    1500000
# 127    1400000
# 111    1400000
# 93     1400000
# Name: PREMIUM, dtype: int64

# %% [markdown]
# ## Group By and Aggregation

# %%
df.groupby(['AGE', 'PLAYING ROLE'])['SOLD PRICE'].mean() #.reset_index() # Average Sold price for a particular age & playing role
# Out:
# AGE  PLAYING ROLE
# 1    Allrounder      5.875000e+05
#      Batsman         1.110000e+06
#      Bowler          5.177143e+05
# 2    Allrounder      4.494000e+05
#      Batsman         6.547619e+05
#      Bowler          3.979310e+05
#      W. Keeper       4.677273e+05
# 3    Allrounder      7.666667e+05
#      Batsman         4.576923e+05
#      Bowler          4.143750e+05
#      W. Keeper       7.000000e+05
# Name: SOLD PRICE, dtype: float64

# %%
df.groupby(['AGE', 'PLAYING ROLE'])['SOLD PRICE'].mean().reset_index()
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %%
df.groupby(['AGE', 'PLAYING ROLE'])['SOLD PRICE'].count()
# Out:
# AGE  PLAYING ROLE
# 1    Allrounder       4
#      Batsman          5
#      Bowler           7
# 2    Allrounder      25
#      Batsman         21
#      Bowler          29
#      W. Keeper       11
# 3    Allrounder       6
#      Batsman         13
#      Bowler           8
#      W. Keeper        1
# Name: SOLD PRICE, dtype: int64

# %% [markdown]
# ## Filtering---equivalent where in sql

# %%
df[df['SIXERS']>80][['PLAYER NAME','SIXERS']].sort_values('SIXERS',ascending = False)
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 88      Raina, SK      97
# 28  Gilchrist, AC      86
# 97     Sharma, RG      82
# 82     Pathan, YK      81

# %% [markdown]
# ## Removing Column or a Row from a DataFrame

# %% [markdown]
# ## Additional EDA

# %%
df['SIXERS'].max()
# Out:
# 129

# %%
df['SIXERS'].min()
# Out:
# 0

# %%
df['SIXERS'].idxmax()
# Out:
# 26

# %%
df.iloc[26]
# Out:
# Sl.NO.                   27
# PLAYER NAME       Gayle, CH
# AGE                       2
# COUNTRY                  WI
# TEAM                   KKR+
# PLAYING ROLE     Allrounder
# T-RUNS                 6373
# T-WKTS                   72
# ODI-RUNS-S             8087
# ODI-SR-B              83.95
# ODI-WKTS                156
# ODI-SR-BL              44.4
# CAPTAINCY EXP             1
# RUNS-S                 1804
# HS                      128
# AVE                   50.11
# SR-B                 161.79
# SIXERS                  129
# RUNS-C                  606
# WKTS                     13
# AVE-BL                46.62
# ECON                   8.05
# SR-BL                 34.85
# AUCTION YEAR           2008
# BASE PRICE           250000
# SOLD PRICE           800000
# PREMIUM              550000
# Name: 26, dtype: object

# %%
df[df['SIXERS']==df['SIXERS'].max()]
# Out:
#     Sl.NO. PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 26      27   Gayle, CH    2      WI  KKR+   Allrounder    6373      72
#
#     ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S   HS  \
# 26        8087     83.95       156       44.4              1    1804  128
#
#       AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  SR-BL  AUCTION YEAR  \
# 26  50.11  161.79     129     606    13   46.62  8.05  34.85          2008
#
#     BASE PRICE  SOLD PRICE  PREMIUM
# 26      250000      800000   550000

# %%
df['SOLD PRICE'].std() ## 406807.351419
# Out:
# 406807.35141926043

# %%
df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].std().reset_index()
# Out:
#     AGE PLAYING ROLE     SOLD PRICE
# 0     1   Allrounder  442295.150324
# 1     1      Batsman  544747.647999
# 2     1       Bowler  356973.254967
# 3     2   Allrounder  377575.378788
# 4     2      Batsman  523606.427077
# 5     2       Bowler  255833.781283
# 6     2    W. Keeper  402283.256154
# 7     3   Allrounder  403009.511881
# 8     3      Batsman  423697.097900
# 9     3       Bowler  178914.135431
# 10    3    W. Keeper            NaN

# %% [markdown]
# ## MELTING -- ASSIGNMENT

# %%
df.melt() ## Assignment regarding PIVOTING and UNPIVOTING

# %% [markdown]
# ### CALCULATING IQR -- ASSIGNMENT

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Univariate

# %%
sns.countplot(df['COUNTRY'].sort_values(ascending = False))
# Out:
# <Axes: xlabel='count', ylabel='COUNTRY'>

# %%
df['AGE'] = df['AGE'].astype('string')

# %%
df['AGE'].unique()
# Out:
# <StringArray>
# ['2', '1', '3']
# Length: 3, dtype: string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    string
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
sns.countplot(df['AGE'])
# Out:
# <Axes: xlabel='count', ylabel='AGE'>

# %%
sns.histplot(df['SOLD PRICE'],kde = True)
# Out:
# <Axes: xlabel='SOLD PRICE', ylabel='Count'>

# %%
sns.kdeplot(df['SOLD PRICE'])
# Out:
# <Axes: xlabel='SOLD PRICE', ylabel='Density'>

# %%
sns.boxplot(df['SOLD PRICE'])
# Out:
# <Axes: ylabel='SOLD PRICE'>

# %% [markdown]
# ## BIVARIATE

# %% [markdown]
# ![image.png](attachment:b160c76e-b34c-4328-b2d2-06f5e9a286b2.png)

# %%
sns.barplot(x = 'AGE', y = 'SOLD PRICE', data = df,errorbar = None)
# Out:
# <Axes: xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sns.pointplot(x = 'AGE', y = 'SOLD PRICE', data = df,errorbar = None)
# Out:
# <Axes: xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sns.scatterplot(x= 'SOLD PRICE', y = 'SIXERS',data =df)
# Out:
# <Axes: xlabel='SOLD PRICE', ylabel='SIXERS'>

# %%
sns.regplot(x= 'SOLD PRICE', y = 'SIXERS',data =df, scatter = False)
# Out:
# <Axes: xlabel='SOLD PRICE', ylabel='SIXERS'>

# %%
sns.lmplot(x= 'SOLD PRICE', y = 'SIXERS',data =df, scatter = False)

# %% [markdown]
# ## MULTIVARIATE ANALYSIS`

# %%
sns.barplot(x = 'AGE', y = 'SOLD PRICE', data = df,errorbar = None, hue = 'PLAYING ROLE')
# Out:
# <Axes: xlabel='AGE', ylabel='SOLD PRICE'>

# %%
sns.scatterplot(x= 'SOLD PRICE', y = 'SIXERS',data =df, hue = 'AGE')
# Out:
# <Axes: xlabel='SOLD PRICE', ylabel='SIXERS'>

# %%
sns.boxplot(df[['SOLD PRICE','BASE PRICE','PREMIUM']]) ## compare distributions
# Out:
# <Axes: >

# %% [markdown]
# ### MISC

# %%
box = plt.boxplot(df['SOLD PRICE'])

# %%
for item in box['caps']:
    print(item.get_ydata()[0])  ## upper and lower limit
# Out:
# 20000
# 1350000

# %%
for item in box['whiskers']:
    print(item.get_ydata()[0]) ### gives q1 and q3
# Out:
# 225000.0
# 700000.0

# %%
for item in box['medians']:
    print(item.get_ydata()[0])
# Out:
# 437500.0

# %%
for i in box.keys():
    print(i)
# Out:
# whiskers
# caps
# boxes
# medians
# fliers
# means

# %%
for i in box['fliers']:
    print(i.get_ydata())
# Out:
# [1500000 1550000 1800000 1550000 1800000 1800000 1600000 1800000]

# %%
outliers = sorted([i.get_ydata() for i in box['fliers']])

# %%
outliers
# Out:
# [array([1500000, 1550000, 1800000, 1550000, 1800000, 1800000, 1600000,
#         1800000])]
